# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()

# %%
df.columns

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
## Job title and seniority 
df['job_simp']= df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    471
# na                187
# analyst           152
# data engineer     110
# mle                43
# director           18
# manager            14
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        794
# senior    201
# Name: seniority, dtype: int64

# %%
##  Fix some states

df['job_state']= df.job_state.apply (lambda x: x.strip () if x.strip().lower() != 'california' else 'CA')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'maryland' else 'MD')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'virginia' else 'VA')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'florida' else 'FL')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'north carolina' else 'NC')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'oregon' else 'OR')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'puerto rico' else 'PR')
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'united states' else 'na')
#df.job_state.value_counts()

# %%
##  Job description length 
df['desc_len'] = df['Job Description'].apply (lambda x: len (x) )

# %%
#remove new line from company_txt
df['company_txt']= df.company_txt.apply(lambda x: x.replace('\n',''))

# %%
df.describe()
# Out:
#            Rating      Founded   min_slary   max_slary   avg_slary  \
# count  995.000000   995.000000  995.000000  995.000000  995.000000
# mean     3.537688  1679.211055   82.484422  142.466332  112.475377
# std      1.297729   714.749308   32.690865   53.509149   42.193637
# min     -1.000000    -1.000000   27.000000   56.000000   42.500000
# 25%      3.400000  1937.000000   55.000000   97.000000   74.500000
# 50%      3.800000  1990.000000   78.000000  122.000000  100.000000
# 75%      4.100000  2007.000000  110.000000  183.000000  153.000000
# max      5.000000  2019.000000  145.000000  244.000000  188.000000
#
#               age   python_yn    spark_yn      aws_yn    excel_yn  \
# count  995.000000  995.000000  995.000000  995.000000  995.000000
# mean    31.900503    0.622111    0.197990    0.270352    0.482412
# std     38.980457    0.485104    0.398685    0.444365    0.499942
# min     -1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.000000    0.000000    0.000000    0.000000    0.000000
# 50%     19.000000    1.000000    0.000000    0.000000    0.000000
# 75%     42.000000    1.000000    0.000000    1.000000    1.000000
# max    231.000000    1.000000    1.000000    1.000000    1.000000
#
#            desc_len
# count    995.000000
# mean    4033.997990
# std     1647.062436
# min      580.000000
# 25%     2952.000000
# 50%     3833.000000
# 75%     4971.500000
# max    12250.000000

# %%
df.Rating.hist()

# %%
df.avg_slary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column=['age','avg_slary','Rating'])

# %%
df.boxplot(column='Rating')

# %%
#correlations
df[['age','avg_slary','Rating','desc_len']].corr()
# Out:
#                 age  avg_slary    Rating  desc_len
# age        1.000000   0.006745  0.146590  0.153853
# avg_slary  0.006745   1.000000 -0.002027  0.027387
# Rating     0.146590  -0.002027  1.000000  0.028255
# desc_len   0.153853   0.027387  0.028255  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_slary','Rating','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_cat=df[['Location', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt','job_state','python_yn', 'spark_yn', 'aws_yn',
       'excel_yn','job_simp','seniority']]

# %%
for i in df_cat.columns:
    cat_num= df_cat[i].value_counts()
    print ("Graph for %s: total= %d" %(i,len(cat_num)))
    chart= sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(  chart.get_xticklabels() ,rotation=90)
    plt.show()
# Out:
# Graph for Location: total= 281
# Graph for Size: total= 9
# Graph for Type of ownership: total= 12
# Graph for Industry: total= 67
# Graph for Sector: total= 24
# Graph for Revenue: total= 14
# Graph for company_txt: total= 536
# Graph for job_state: total= 48
# Graph for python_yn: total= 2
# Graph for spark_yn: total= 2
# Graph for aws_yn: total= 2
# Graph for excel_yn: total= 2
# Graph for job_simp: total= 7
# Graph for seniority: total= 2

# %%
for i in df_cat[['Location','company_txt']].columns:
    cat_num= df_cat[i].value_counts()[:20]
    print ("Graph for %s: total= %d" %(i,len(cat_num)))
    chart= sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(  chart.get_xticklabels() ,rotation=90)
    plt.show()
# Out:
# Graph for Location: total= 20
# Graph for company_txt: total= 20

# %%
pd.pivot_table(df,index=['job_simp','seniority'],values='avg_slary')
# Out:
#                            avg_slary
# job_simp       seniority
# analyst        na         107.981481
#                senior      89.420455
# data engineer  na         115.230337
#                senior     119.166667
# data scientist na         118.695274
#                senior     104.340580
# director       na         103.071429
#                senior     111.636364
# manager        na         129.535714
# mle            na         103.100000
#                senior     138.500000
# na             na         106.032374
#                senior     113.031250

# %%
pd.pivot_table(df,index='job_state',values='avg_slary').sort_values('avg_slary', ascending=False)
# Out:
#             avg_slary
# job_state
# WV         188.000000
# DE         165.000000
# VI         154.250000
# AK         148.000000
# KS         148.000000
# MI         144.555556
# PR         144.000000
# MT         144.000000
# AL         140.500000
# KY         133.500000
# WI         129.772727
# IL         129.333333
# WA         124.545455
# NY         123.763889
# MN         123.700000
# NE         119.000000
# Remote     116.796875
# CA         116.136585
# UT         114.909091
# TN         114.176471
# FL         112.700000
# MA         112.568966
# MD         112.388889
# DC         112.078947
# NV         112.000000
# PA         111.450000
# NJ         110.537037
# OR         109.727273
# TX         108.730769
# VA         108.111538
# GA         107.235294
# OH         104.847826
# NC         103.083333
# CT         101.785714
# IA         101.333333
# na          96.062500
# MO          95.952381
# IN          94.375000
# AZ          88.916667
# CO          87.421053
# RI          84.500000
# AR          84.500000
# NH          83.000000
# NM          82.000000
# MS          79.750000
# SC          71.000000
# OK          70.000000
# ID          56.000000

# %%
pd.pivot_table(df,index=['job_state','job_simp'],values='avg_slary', aggfunc="count").sort_values('job_state', ascending=False)
# Out:
#                           avg_slary
# job_state job_simp
# na        na                      1
#           mle                     1
#           data scientist          3
#           data engineer           3
# WV        na                      1
# ...                             ...
# AZ        data engineer           2
# AR        data scientist          1
# AL        na                      2
#           analyst                 1
# AK        na                      1
#
# [142 rows x 1 columns]

# %%
#display all values
pd.set_option('display.max_rows',None)

# %%
pd.pivot_table(df[df.job_simp=='data scientist'],index='job_state',values='avg_slary').sort_values('avg_slary', ascending=False)
# Out:
#             avg_slary
# job_state
# IA         148.000000
# WI         148.000000
# KS         148.000000
# NY         138.947368
# MI         138.625000
# OR         136.400000
# KY         133.500000
# MD         127.200000
# WA         126.611111
# NJ         125.307692
# IL         124.888889
# MN         124.500000
# TX         122.704545
# CA         119.559829
# Remote     118.884615
# VA         116.367188
# FL         113.312500
# GA         111.550000
# DC         111.375000
# MA         108.381579
# CT         105.666667
# PA         105.588235
# TN         105.083333
# NC          99.428571
# na          96.833333
# UT          96.333333
# OH          94.600000
# MO          85.933333
# AR          84.500000
# CO          79.750000
# MS          79.000000

# %%
#rating, insustry, sector, revenue, python, spark, aws,excel, desc_len, type of ownership
df_pivots= df[['Rating', 'Industry', 'Sector', 'Revenue', 'python_yn', 'spark_yn','aws_yn','excel_yn','Type of ownership','avg_slary']]

# %%
for i in df_pivots.columns[:-1]:
    print(i)
    print (pd.pivot_table(df_pivots,index=i,values='avg_slary').sort_values('avg_slary',ascending=False))
# Out:
# Rating
#          avg_slary
# Rating
#  2.2    160.125000
#  4.0    123.086207
#  4.1    121.591549
#  2.0    121.500000
#  2.7    120.583333
#  4.8    120.214286
#  3.5    118.100000
#  2.8    118.055556
#  5.0    116.525000
#  4.2    116.297619
#  3.3    115.663043
#  4.4    115.555556
#  3.0    114.684211
#  3.2    114.661765
#  3.9    113.604167
#  3.8    113.597561
#  4.7    113.218750
# -1.0    113.198413
#  3.4    113.148649
#  3.1    111.807692
#  3.6    111.405172
#  4.9    110.500000
#  4.6    102.275862
#  3.7    101.868182
#  4.3    101.531250
#  4.5    100.588235
#  2.6     88.300000
#  2.9     87.785714
#  2.4     82.750000
#  2.3     62.250000
#  1.8     58.000000
# Industry
#                                           avg_slary
# Industry
# Grantmaking Foundations                  170.500000
# Trucking                                 165.500000
# Food & Beverage Stores                   154.000000
# Beauty & Personal Accessories Stores     148.000000
# Brokerage Services                       148.000000
# Mining                                   148.000000
# Hotels, Motels, & Resorts                146.000000
# Logistics & Supply Chain                 144.142857
# Video Games                              141.900000
# Insurance Agencies & Brokerages          138.125000
# Financial Transaction Processing         136.400000
# Advertising & Marketing                  131.166667
# Chemical Manufacturing                   131.000000
# Electrical & Electronic Manufacturing    128.823529
# Consumer Products Manufacturing          127.400000
# Telecommunications Manufacturing         127.000000
# Transportation Management                127.000000
# General Repair & Maintenance             127.000000
# Federal Agencies                         126.734375
# Wholesale                                122.375000
# Health Care Services & Hospitals         121.353659
# Investment Banking & Asset Management    120.676471
# Industrial Manufacturing                 120.625000
# -1                                       118.760417
# Research & Development                   116.500000
# Lending                                  116.250000
# Computer Hardware & Software             115.625000
# Miscellaneous Manufacturing              114.750000
# Insurance Carriers                       114.700000
# Education Training Services              114.428571
# Internet                                 112.918367
# Security Services                        112.000000
# Enterprise Software & Network Solutions  111.333333
# Social Assistance                        110.375000
# Food & Beverage Manufacturing            107.750000
# Biotech & Pharmaceuticals                107.656250
# Aerospace & Defense                      107.416667
# Accounting                               107.333333
# Architectural & Engineering Services     106.916667
# Health, Beauty, & Fitness                105.700000
# Utilities                                103.000000
# IT Services                              102.540541
# Venture Capital & Private Equity         102.250000
# Oil & Gas Services                       102.250000
# Metals Brokers                           102.250000
# Health Fundraising Organizations         102.250000
# Gas Stations                             102.250000
# Health Care Products Manufacturing       101.750000
# Financial Analytics & Research           100.777778
# Transportation Equipment Manufacturing   100.142857
# Energy                                   100.136364
# Staffing & Outsourcing                    99.342857
# Consulting                                98.616071
# Colleges & Universities                   95.875000
# Building & Personnel Services             95.857143
# Telecommunications Services               94.000000
# Banks & Credit Unions                     92.857143
# Department, Clothing, & Shoe Stores       89.500000
# Real Estate                               84.000000
# Publishing                                83.000000
# Other Retail Stores                       76.500000
# Food Production                           75.500000
# Oil & Gas Exploration & Production        70.000000
# Grocery Stores & Supermarkets             70.000000
# Home Furniture & Housewares Stores        61.000000
# Religious Organizations                   47.500000
# Cable, Internet & Telephone Providers     44.000000
# Sector
#                                      avg_slary
# Sector
# Transportation & Logistics          148.076923
# Travel & Tourism                    146.000000
# Construction, Repair & Maintenance  127.000000
# Government                          126.734375
# Health Care                         121.353659
# -1                                  118.760417
# Insurance                           117.931034
# Mining & Metals                     117.500000
# Manufacturing                       116.762500
# Media                               115.722222
# Non-Profit                          114.944444
# Finance                             113.626761
# Information Technology              109.985043
# Education                           107.681818
# Biotech & Pharmaceuticals           107.656250
# Aerospace & Defense                 107.416667
# Accounting & Legal                  107.333333
# Consumer Services                   105.700000
# Business Services                   105.559259
# Telecommunications                   97.200000
# Oil, Gas, Energy & Utilities         97.176471
# Retail                               96.000000
# Real Estate                          84.000000
# Agriculture & Forestry               75.500000
# Revenue
#                                    avg_slary
# Revenue
# Less than $1 million (USD)        132.842105
# $5 to $10 million (USD)           131.537037
# $1 to $5 million (USD)            116.586207
# $100 to $500 million (USD)        116.340426
# Unknown / Non-Applicable          114.147059
# $1 to $2 billion (USD)            113.851852
# $10+ billion (USD)                110.564000
# -1                                110.397959
# $500 million to $1 billion (USD)  109.804348
# $2 to $5 billion (USD)            109.788889
# $50 to $100 million (USD)         107.682692
# $10 to $25 million (USD)          101.927083
# $5 to $10 billion (USD)           101.660000
# $25 to $50 million (USD)           97.520833
# python_yn
#             avg_slary
# python_yn
# 1          113.460420
# 0          110.853723
# spark_yn
#            avg_slary
# spark_yn
# 1         113.741117
# 0         112.162907
# aws_yn
#          avg_slary
# aws_yn
# 1       113.962825
# 0       111.924242
# excel_yn
#            avg_slary
# excel_yn
# 1         112.560417
# 0         112.396117
# Type of ownership
#                                  avg_slary
# Type of ownership
# Private Practice / Firm         144.333333
# Government                      134.291667
# Other Organization              131.888889
# Unknown                         127.500000
# Hospital                        123.300000
# Company - Private               113.652985
# Nonprofit Organization          112.034247
# -1                              110.397959
# Company - Public                109.304781
# Contract                        102.000000
# Subsidiary or Business Segment  100.185714
# College / University             90.500000
# avg_slary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-2678576f4b85> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print (pd.pivot_table(df_pivots,index=i,values='avg_slary').sort_values('avg_slary',ascending=False))
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      98         values = list(values)
#      99
# --> 100     grouped = data.groupby(keys, observed=observed)
#     101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     615         # allow us to passing the actual Grouping as the gpr
#     616         ping = (
# --> 617             Grouping(
#     618                 group_axis,
#     619                 gpr,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     343                 if getattr(self.grouper, "ndim", 1) != 1:
#     344                     t = self.name or str(type(self.grouper))
# --> 345                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     346                 self.grouper = self.index.map(self.grouper)
#     347                 if not (
#
# ValueError: Grouper for 'avg_slary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns ='python_yn', values= 'avg_slary', aggfunc='count')

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
